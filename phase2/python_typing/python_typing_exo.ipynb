# %% [markdown]
# # Typage en Python – Parcours progressif
#
# Ce notebook est destiné à la découverte du typage en python.
#
# ## Plan du notebook
# 1. Rappels : types de base en Python (sans annotations)
# 2. Annotations simples (variables et fonctions)
# 3. Collections typées & syntaxes modernes/anciennes
# 4. Types avancés : `Optional`, `Union`, `Any`, `Literal`
# 5. Classes comme types
# 6. Alias de types et `Annotated`
# 7. Fonctions génériques avec `TypeVar`
# 8. Modèles Pydantic comme types (lien avec FastAPI)
# 9. Outils de vérification de type (`mypy`, `pyright`) et motivation
#
# Les cellules contenant `# TODO` sont à compléter par vous.

# %% [markdown]
# ## 1. Rappels : types de base en Python
#
# Avant de parler de typage statique, rappelons les principaux types intégrés de Python :
#
# - `int` : nombres entiers
# - `float` : nombres à virgule flottante
# - `bool` : booléens (`True` / `False`)
# - `str` : chaînes de caractères
# - `list` : listes
# - `tuple` : tuples
# - `dict` : dictionnaires
# - `set` : ensembles (sans doublons)
#
# Dans cette section, **on n’utilise pas encore les annotations de type**.

# %%
# TODO 1.1 : créer au moins une variable de chaque type de base indiqué ci-dessous
# puis utiliser print(type(...)) pour afficher leur type réel.

# Exemple pour commencer :
exemple_entier = 42
print(type(exemple_entier))

# Votre code :
# entier = ...
# reel = ...
# est_vrai = ...
# message = ...
# liste = ...
# tuple_valeurs = ...
# dico = ...
# ensemble = ...

# %% [markdown]
# ### Exercice 1.2 – Identifier les types
#
# Complétez les commentaires avec le type attendu, puis exécutez la cellule pour vérifier avec `type(...)`.

# %%
# TODO 1.2 : compléter les commentaires avec le type attendu

age = 25          # type : ?
prix = 19.99      # type : ?
nom = "Alice"     # type : ?
est_connecte = False  # type : ?
fruits = ["pomme", "banane", "poire"]  # type : ?
coordonnees = (48.8, 2.3)  # type : ?
config = {"debug": True, "version": 1}  # type : ?

print(type(age))
print(type(prix))
print(type(nom))
print(type(est_connecte))
print(type(fruits))
print(type(coordonnees))
print(type(config))

# %% [markdown]
# ## 2. Annotations de type simples
#
# Python permet d’**annoter** les variables et les fonctions pour indiquer les types attendus.
#
# Exemples :
#
# ```python
# x: int = 3
# nom: str = "Alice"
#
# def ajouter(a: int, b: int) -> int:
#     return a + b
# ```
#
# ⚠️ Ces annotations ne sont pas vérifiées par Python à l’exécution :
# elles servent aux outils (IDE, mypy, pyright) et à la documentation.

# %%
# TODO 2.1 : ajouter des annotations aux variables ci-dessous

# x = 3
# titre = "Cours de Python"
# est_actif = True

# Ensuite, affichez-les avec print(x, titre, est_actif)

# %% [markdown]
# ### 2.2 – Annotations de fonction
#
# On peut annoter :
# - les paramètres
# - le type de retour avec `-> ...`.
#
# Exemple :
#
# ```python
# def ajouter(a: int, b: int) -> int:
#     return a + b
# ```

# %%
# TODO 2.2 : ajouter les annotations de type appropriées

# La fonction prend un nom et ne retourne rien (None).

def dire_bonjour(nom):
    print(f"Bonjour {nom} !")

# Test
# dire_bonjour("Alice")
# dire_bonjour(123)  # Que se passe-t-il à l'exécution ?

# %% [markdown]
# ## 3. Collections typées & syntaxes modernes/anciennes
#
# Pour les collections, on peut préciser le type des éléments.
#
# ### Syntaxe moderne (Python 3.9+)
#
# - `list[int]`
# - `dict[str, float]`
# - `set[str]`
# - `tuple[int, str]`
#
# ### Syntaxe ancienne (versions < 3.9)
#
# - `List[int]` (avec `from typing import List`)
# - `Dict[str, float]` (avec `from typing import Dict`)
#
# Les deux syntaxes signifient la même chose pour un type checker.

# %%
# TODO 3.1 : créer deux listes typées :
# - une liste de nombres entiers
# - une liste de chaînes de caractères
# en utilisant la syntaxe moderne.

# nombres: list[int] = ...
# noms: list[str] = ...

# print(nombres)
# print(noms)

# %%
# TODO 3.2 : créer un dictionnaire typé avec la syntaxe moderne
# Les clés seront des str (noms d'étudiants) et les valeurs des float (notes).

# notes: dict[str, float] = ...
# print(notes)

# %%
# TODO 3.3 : écrire une fonction compter_noms qui :
# - prend en paramètre une liste de str
# - retourne un int (la taille de la liste)

# def compter_noms(noms) -> int:
#     ...

# print(compter_noms(["Alice", "Bob"]))
# print(compter_noms([]))

# %% [markdown]
# ## 4. Types avancés : `Optional`, `Union`, `Any`, `Literal`
#
# On utilise le module `typing` pour exprimer des types plus riches.
#
# - `Optional[T]` signifie : `T` ou `None`.
# - `Union[A, B]` signifie : A **ou** B.
# - `Any` désactive le typage statique.
# - `Literal[...]` restreint à quelques valeurs précises.

# %%
# TODO 4.1 : compléter les annotations de type avec Optional
from typing import Optional

# La fonction doit accepter un prénom optionnel (str ou None)
# et ne rien retourner (None). Si le prénom est None, afficher
# "Bonjour le monde !", sinon "Bonjour <prenom> !".

# def dire_bonjour_optional(prenom) -> ...:
#     ...

# Tests possibles :
# dire_bonjour_optional("Alice")
# dire_bonjour_optional(None)

# %%
# TODO 4.2 : utiliser Union pour définir un type Nombre (int ou float)
from typing import Union

# Nombre = ...

# def doubler(x: Nombre) -> Nombre:
#     ...

# print(doubler(10))
# print(doubler(3.14))

# %%
# TODO 4.3 : expérimenter Any
from typing import Any

# Créez une variable valeur de type Any, affectez-lui successivement
# un int, une str, puis une list.

# valeur: Any = ...
# print(valeur, type(valeur))

# valeur = ...
# print(valeur, type(valeur))

# valeur = ...
# print(valeur, type(valeur))

# %%
# TODO 4.4 : utiliser Literal pour restreindre quelques valeurs possibles
from typing import Literal

# Définir un type Couleur qui ne peut valoir que "rouge", "vert" ou "bleu".
# Puis écrire une fonction afficher_couleur(c: Couleur) -> None qui affiche la couleur.

# Couleur = ...

# def afficher_couleur(c: Couleur) -> None:
#     ...

# afficher_couleur("rouge")
# afficher_couleur("jaune")  # Que dirait un type checker ?

# %% [markdown]
# ## 5. Classes comme types
#
# Une classe peut aussi être utilisée comme type dans les annotations.
#
# ```python
# class User:
#     def __init__(self, name: str, age: int) -> None:
#         self.name = name
#         self.age = age
#
# def show_user(user: User) -> None:
#     print(user.name, user.age)
# ```

# %%
# TODO 5.1 : définir une classe User puis une fonction show_user

# class User:
#     def __init__(self, name: str, age: int) -> None:
#         ...

# def show_user(user: User) -> None:
#     ...

# u = User("Alice", 30)
# show_user(u)

# %%
# TODO 5.2 : créer une classe Product et une fonction print_product

# class Product:
#     def __init__(self, name: str, price: float) -> None:
#         ...

# def print_product(p: Product) -> None:
#     ...

# p = Product("Stylo", 1.5)
# print_product(p)

# %% [markdown]
# ## 6. Alias de types et `Annotated`
#
# On peut créer des **alias de types** pour rendre le code plus lisible :
#
# ```python
# UserId = int
# Score = float
# ```
#
# Avec `Annotated`, on peut associer des **métadonnées** à un type, ce qui est utilisé par des frameworks comme FastAPI.
#
# ```python
# from typing import Annotated
#
# UserId = Annotated[int, "Identifiant d'utilisateur"]
# ```

# %%
# TODO 6.1 : créer quelques alias de type simples

# UserId = ...  # basé sur int
# Price = ...   # basé sur float

# def display_price(p: Price) -> None:
#     ...

# display_price(9.99)

# %%
# TODO 6.2 : utiliser Annotated pour un identifiant utilisateur et un email
from typing import Annotated

# UserId = Annotated[int, "Identifiant d'utilisateur"]
# EmailStr = Annotated[str, "Adresse email"]

# def send_email(to: EmailStr, subject: str, body: str) -> None:
#     ...

# send_email("test@example.com", "Sujet", "Corps du message")

# %% [markdown]
# ## 7. Fonctions génériques avec `TypeVar`
#
# Un `TypeVar` permet de définir une fonction générique qui fonctionne avec différents types,
# tout en conservant l'information de type.
#
# ```python
# from typing import TypeVar
#
# T = TypeVar("T")
#
# def identite(x: T) -> T:
#     return x
# ```

# %%
# TODO 7.1 : écrire une fonction identite générique
from typing import TypeVar

# T = TypeVar("T")

# def identite(x: T) -> T:
#     ...

# print(identite(42))
# print(identite("hello"))
# print(identite([1, 2, 3]))

# %%
# TODO 7.2 : écrire une fonction dernier_element générique
from typing import TypeVar

# U = TypeVar("U")

# def dernier_element(items: list[U]) -> U | None:
#     ...

# print(dernier_element([1, 2, 3]))
# print(dernier_element(["a", "b"]))
# print(dernier_element([]))

# %% [markdown]
# ## 8. Modèles Pydantic comme types (lien avec FastAPI)
#
# FastAPI utilise **Pydantic** pour définir des modèles de données **typés** et **validés**.
#
# ```python
# from pydantic import BaseModel
#
# class UserModel(BaseModel):
#     id: int
#     name: str
#     is_active: bool = True
# ```
#
# Ces modèles peuvent être utilisés comme types dans les annotations de fonctions.

# %%
# TODO 8.1 : si Pydantic est disponible, définir un modèle UserModel
# avec les champs : id: int, name: str, is_active: bool = True
# puis écrire une fonction deactivate(user: UserModel) -> UserModel
# qui passe is_active à False.

try:
    from pydantic import BaseModel
except ImportError:
    BaseModel = None

if BaseModel is not None:
    # class UserModel(BaseModel):
    #     ...

    # def deactivate(user: UserModel) -> UserModel:
    #     ...

    # u = UserModel(id=1, name="Alice")
    # print(u)
    # u = deactivate(u)
    # print(u)
    ...
else:
    print("Pydantic n'est pas installé dans cet environnement.")

# %% [markdown]
# ## 9. Motivation : pourquoi typer ? et outils de vérification
#
# Exemple inspiré de la doc FastAPI :
#
# ```python
# def get_full_name(first_name, last_name):
#     full_name = first_name.title() + " " + last_name.title()
#     return full_name
# ```
#
# Cette fonction marche sans types, mais :
# - l'éditeur ne sait pas quels sont les types
# - un appel incorrect ne sera pas repéré avant l'exécution.
#
# Avec des annotations :
#
# ```python
# def get_full_name(first_name: str, last_name: str) -> str:
#     ...
# ```
#
# Un type checker peut alors signaler les erreurs.

# %%
# TODO 9.1 : ajouter des types à cette fonction puis imaginer des appels incorrects

# def get_full_name(first_name, last_name):
#     full_name = first_name.title() + " " + last_name.title()
#     return full_name

# Ajoutez les annotations de type appropriées puis testez des appels comme :
# get_full_name("john", "doe")
# get_full_name(123, "doe")  # que dirait un type checker ?

# %% [markdown]
# ### 9.2 – Outils : `mypy` et `pyright`
#
# Les annotations seules ne suffisent pas : il faut un outil pour les vérifier.
#
# - Installation de mypy :
#
# ```bash
# pip install mypy
# mypy mon_fichier.py
# ```
#
# - Installation de pyright :
#
# ```bash
# npm install -g pyright
# pyright mon_fichier.py
# ```
#
# Ces outils signalent les incohérences de types **avant l'exécution**.
